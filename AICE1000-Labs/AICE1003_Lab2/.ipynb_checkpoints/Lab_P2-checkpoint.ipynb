# %% [markdown]
# # AICE1003 - Lab P2 - Loops, Functions, and Lists

# %% [markdown]
# ## 1. Introduction
# ### 1.1. Aims and Learning Outcomes
# This laboratory aims to:
# - Understand loops and how to use them
# - Understand functions, how to define and call functions
# - Understand lists and operations on lists including list comprehension.
#
# When you complete this laboratory, you will be to:
# - Write a simple program using loops to model repetitive behaviours
# - Write a program with functions to have better code structures with correct type annotations.
# - Utilise the list data structure and use operators to update lists.
#
# ### 1.2. Schedule
# - Preparation Time: 1 hour
# - Lab Time: 3 hours
#
# ### 1.3. Required Items
# - (Optional) Your logbook + pen
# - (Optional) Your laptop with software ready to use (i.e., as instructed in Lab [P0](https://moodle.ecs.soton.ac.uk/mod/lesson/view.php?id=2747))
#
# ### 1.4. Conventions
# | Symbols | Explanation |
# | ------- | ----------- |
# |![logbook entry](logbook.png "Logbook") | An entry should be made in your logbook |
# |```code``` | Code to be entered (e.g., command line or to an editor) |
# |![Be careful](small-attention.png "alert") | Care should be exercised |
#
# ### 1.5. Instructions
# Before starting the lab, you should complete the preparation tasks on the next page and take the [P2 Preparation Quiz](https://moodle.ecs.soton.ac.uk/mod/quiz/view.php?id=3268). The preparation quiz deadline is **16:00 on Friday 1st November 2024 (Week 5)**.
#
# You will undertake the lab working individually. During the lab, yo*u shou*ld use your logbook to record what you have done, and what works and what does nrk. You can refer to the logbook in the future, e.g., to remind you about the procedures or how you overcome problems. As such, it should be legible, and the notes should be clearly referenced to the appropriate part of the lab. You will be informed when yoshouldst makenry entry in your logbook. However, you are encouraged to record additional entries, especially when something unexpected occurs, or when you discover something of interest.
#
# You will take quizzes on Progress and Understanding. The deadline for completing [t2e P1 Progress ](https://moodle.ecs.soton.ac.uk/mod/quiz/view.php?id=3269)Quiz [a2d P1 Understanding ](https://moodle.ecs.soton.ac.uk/mod/quiz/view.php?id=3270)Quiz is 16:00 on Fri8th 1st November 2024 (W6ek 5).
#
# There wil5 be 20 marks for2Lab P0:
#
# Preparation Quiz: 6
# Progress Quiz: 8
# Understanding Quiz: 11

# %% [markdown]
# ## Prep
#
# You will need to:
# - Read https://introcs.cs.princeton.edu/python/13flow/
# - Review this week's slides
#
# In this lab you will be using the following Python datatypes, functions and modules predfined in Python, read the following documentation:
# - https://docs.python.org/3/library/functions.html#int
# - https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str
# - https://docs.python.org/3/library/functions.html#bool
# - https://docs.python.org/3/library/functions.html#print
# - https://docs.python.org/3/library/functions.html#input
# - https://docs.python.org/3/library/functions.html#int
# - https://docs.python.org/3/library/functions.html#float
# - https://docs.python.org/3/library/functions.html#func-range
# - https://docs.python.org/3/library/random.html#random.randint
# - https://docs.python.org/3/tutorial/controlflow.html#defining-functions
# - https://docs.python.org/3/library/random.html
#
# Answer the following questions in your logbook:
#
# 1. What will be the output of `int("123.45")`?
#
#     a) `123`
#
#     b) `123.45`
#
#     c) `ValueError`
#
#     d) `None`
#
#
# 2. Which of the following statements would evaluate to true?
#
#     a) `bool("False")`
#
#     b) `bool(0)`
#
#     c) `bool(7)`
#
#     d) `bool("true")`
#
#
# 3. What value will be stored in the variable `z` in the following code?
#
#     `x = "Hello"`
#
#     `y = 123`
#
#     `z = x + y`
#
#     a) "Hello123"
#
#     b) 123
#
#     c) TypeError
#
#     d) "Hello"
#
#
# 4. Which of the following uses positional arguments correctly?
#
#     a) `print(sep=",", "Hello", "World")`
#
#     b) `print("Hello", "World", sep=",")`
#
#     c) `print("Hello", sep=",", "World")`
#
#     d) `print("Hello", "World", sep:=",")`
#
#
# 5. Which function call is equivalent to `range(1, 10, 2)` according to the equals operator?
#
#     a) `range(10)`
#
#     b) `range(1, 10)`
#
#     c) `range(1, 11, 2)`
#
#     d) `range(2, 10, 1)`
#
#
# 6. What does the `randint(a, b)` function do?
#
#     a) Returns a random `float` between `a` and `b` inclusive
#
#     b) Returns a random `int` between `a` and `b-1` inclusive
#
#     c) Returns a random `int` between `a` and `b` inclusive
#
#     d) Returns a random `int` between `0` and `a` inclusive
#
#
# 7. What is the scope of a variable defined inside a function in Python?
#
#     a) Global
#
#     b) Local to the function
#
#     c) Local to the module
#
#     d) Local to the class
#
#
# 8. Which of the following correctly defines a function with default arguments?
#
#     a) `def func(a=1, b): pass`
#
#     b) `def func(a, b=1): pass`
#
#     c) `def func(a=1, b=2): pass`
#
#     d) `def func(a, b): pass`
#
#
# 11. The `input()` function always returns a string regardless of user input.
#
#     True
#
#     False
#
#
# 12. The `float()` function can be used to convert any value to a floating-point type.
#
#     True
#
#     False
#
#
# 13. The `range()` function can generate a sequence of numbers in descending order.
#
#     True
#
#     False
#
#
# 14. The `print()` function cannot print multiple variables of different types.
#
#     True
#
#     False

# %% [markdown]
# ## Lab 2
#
# The lab will be in two sections:
# - the first part will be completed in this notebook
# - the second you will code in a separate editor
#
# ### Part 1 : Guessing Game
#
# You are now going to work on a guessing game example. The core logic is already written however it is not easy to play.
#
# You need to:
# - Add hints for the play, for example 'too high', 'too low', and 'you're very close' when your guess is within 10
# - Keep track of how many guesses it takes to guess the number correctly, and print this number after the "Correct" message

# %%
import random

random.seed(42)
number = random.randint(1, 50)

# collect the guessed number from the keyboard input
guess = int(input('Guess a number: '))

# game logic
while guess != number:
    if guess < number: 
        print('Wrong')
    if guess > number: 
        print('Wrong')
    guess = int(input('Guess a number: '))
print('Correct')

# %% [markdown]
# ### 1.2: Celsius and Fahrenheit
#
# The code below contains a convertToFahrenheit function that converts celsius to fahrenheit. It uses the following formula:
#
# - Fahrenheit = Celsius × (9 / 5) + 32
#
# Edit the code so that:
# - the function returns a whole number (`int`) and not a decimal (`float`)
# - the input is an `int` not a string

# %%
def convertToFahrenheit(celsius):
    fahrenheit = (1.8 * celsius) + 32
    # change the line below
    return fahrenheit
    
celsius = input("Enter the Temperature in Celsius :")
print("Temperature in Fahrenheit :", convertToFahrenheit(celsius))

# %% [markdown]
# The following Python assert statements stop the program if their condition is False. Your solution is correct if the following assert statements’ conditions are all True:

# %%
assert convertToFahrenheit(0) == 32
assert convertToFahrenheit(100) == 212

# %% [markdown]
# Using the convertToFahrenheit as a template, write the corresponding code for `covertToCelsius`, and to read in a value and convert it. Make sure to:
# - use the formula Celsius = (Fahrenheit - 32) × (5 / 9)
# - write the `convertToCelsius` function so that it returns a whole number (`int`)
# - check that you've inputted an int not a string

# %% [markdown]
# Your solution is correct if the following assert statements’ conditions are all True:

# %%
assert convertToCelsius(0) == -18
assert convertToCelsius(100) == 38
assert convertToCelsius(convertToFahrenheit(15)) == 15

# %% [markdown]
# ## Part 2 - Monster Room Game
#
# You will code this game using a simple Text Editor, running your code from a terminal to test it.
#
# You will write a simple text-based adventure game where the player can move through rooms. The player will start in a room with three doors. They can choose to go through any of the door into a different room. Rooms will either have something to pick up, a monster, or treasure. The player can choose to fight the monster or flee. If they find the treasure, they win the game. If they are defeated by the monster, they lose the game.
#
# In our implementation, each room will have a corresponding function, which we will call when the player enters the room.
#
# ### Step 1 - Define the `treasure_room()` Function
#
# When a player enters this room they will find a treasure chest.
#
# - Define the `treasure_room()` Function
# - Print a message indicating the player has won the game.
#
# ### Step 2 - Define the `item_room()` Function
#
# You will start by creating the `item_room()` which contains a random item from a list. First:
#
# - Start by importing the `randint` function from the random module, which will be used to generate random numbers throughout the game
# - Create a global list of named `room_items` that contains various items a player might find in a room, you haven't learned about this yet but this will be covered next week in lectures. Cut and paste the following line in your code so that it is globally accessible.

# %%
room_items = ["bow", "bomb bag", "boomerang", "shield", "sword"]

# %% [markdown]
# - Define the `item_room()` function
#     - Generate a random number that will be used to select an item from the `room_items` list
#     - Print a message indicating the player has found an item from the room_things list and has picked it up.
#     - As this is a very simple text adventure, we will simply return to the previous room once the player has picked up the item by using a `return` statement

# %% [markdown]
# ### Step 3 - Define the `monster_room()` Function
#
# This function simulates a room with a monster.
# - Print a message stating the player has entered a room with a monster.
# - Print a prompt for the user to choose whether to fight or flee.
#     - If the player chooses to fight, call another function to handle the fight and print the result of the fight before returning to the previous room
#     - If the player chooses to flee, print a message stating that the player fled back to the previous room and immediately return from the function, to simulate going back to the previous room.
# - If the input is invalid, it will prompt the player again to make a valid choice.
#
# ### Step 4 - Define the `fight_monster()` Function
#
# This function simulates fighting a monster, and will return either `True` or `False` depending on the outcome of the fight.
# - Print a message indicating the fight has begun.
# - Using the `randint` function, generate a random number between 0 and 10
#     - If the random number is greater than 3 then the player will defeat the monster: return `True` if this is the case
#     - Otherwise, the player is defeated: return `False` if this is the case
# - Now update the `monster_room()` function so that it returns the result of calling `fight_monster()` when the player chooses to fight, and return `True` if the player chooses to flee: these values will be used by the `starting_room()` function, which we will write next.
#
# ### Step 5 - Define the `starting_room()` Function
#
# This function initialises the game and manages the player's choices.
#
# - Create a variable that will store the number of doors in the game, for testing purposes set this to 3
# - Generate a random number between 1 and the total number of doors to be the number of the door to the treasure room, and record it in a suitably named variable
# - Print a message indicating that the player is in a room with the defined number of doors.
# - Inside a `while` loop, prompt the player to choose a door to enter.
#     - If the player chooses the treasure room door, call the treasure room function and terminate the `while` loop.
#     - If the player chooses an incorrect door, randomly determine if the player finds an item or encounters a monster.
#     - If the player encounters a monster, print a message telling the player that they've entered this room and call the `monster_room()` function, conditioning on its return value:
#         - If the player was defeated, end the game. Think about your use of the `while` loop.
#         - If the player survives the encounter, continue with the `while` loop
#
# ### Step 6 - Run the Game
#
# Finally, call the `starting_room()` function to run the game. Where you call this function within the file is important.
#
# ### Lab Extension
#
# If you have time:
# - record the rooms that the player visited
# - record the items that the player has picked up and if the player has something that will help them defeat the monster increase the chance that the monster is defeated.
